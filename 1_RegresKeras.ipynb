# %% [markdown]
# <a href="https://colab.research.google.com/github/chandan3324/Deep-Learning/blob/main/1_RegresKeras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regression with Keras

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# ### Step 1 - Data Ingestion
# Read the training data

# %%
url1 = "https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/refs/heads/main/PowerPlant.csv"
print(url1)
# Out:
# https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/refs/heads/main/PowerPlant.csv

# %%
import pandas as pd
df = pd.read_csv(url1)
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 4  11.80  40.66  1017.13  97.20  464.43

# %% [markdown]
# ### Target - PE - Power Output in MegaWatts
# 1. AT - Atmospheric Temperature in Degree Celsius
# 2. V - Vacuum Pressure of Boiler
# 3. AP - Atmospheric Pressure
# 4. RH - Relative Humidity in Percentage

# %% [markdown]
# ### Step 2 - Perform Basic data quality checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      9568 non-null   float64
#  1   V       9568 non-null   float64
#  2   AP      9568 non-null   float64
#  3   RH      9568 non-null   float64
#  4   PE      9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %%
df.isna().sum()
# Out:
# AT    0
# V     0
# AP    0
# RH    0
# PE    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 41

# %%
df = df.drop_duplicates(keep="first").reset_index(drop=True)
df
# Out:
#          AT      V       AP     RH      PE
# 0      8.34  40.77  1010.84  90.01  480.48
# 1     23.64  58.49  1011.40  74.20  445.75
# 2     29.74  56.90  1007.15  41.91  438.76
# 3     19.07  49.69  1007.22  76.79  453.09
# 4     11.80  40.66  1017.13  97.20  464.43
# ...     ...    ...      ...    ...     ...
# 9522  15.12  48.92  1011.80  72.93  462.59
# 9523  33.41  77.95  1010.30  59.72  432.90
# 9524  15.99  43.34  1014.20  78.66  465.96
# 9525  17.65  59.87  1018.58  94.65  450.93
# 9526  23.68  51.30  1011.86  71.24  451.67
#
# [9527 rows x 5 columns]

# %% [markdown]
# ### Step 3 - Seperate X and Y(PE)

# %%
X = df.drop(columns=["PE"])
Y = df[["PE"]]

# %%
X.head()
# Out:
#       AT      V       AP     RH
# 0   8.34  40.77  1010.84  90.01
# 1  23.64  58.49  1011.40  74.20
# 2  29.74  56.90  1007.15  41.91
# 3  19.07  49.69  1007.22  76.79
# 4  11.80  40.66  1017.13  97.20

# %%
Y.head()
# Out:
#        PE
# 0  480.48
# 1  445.75
# 2  438.76
# 3  453.09
# 4  464.43

# %% [markdown]
# ### Step 4 - Apply Preporcessing on X

# %%
X.dtypes
# Out:
# AT    float64
# V     float64
# AP    float64
# RH    float64
# dtype: object

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
num_pipe = make_pipeline(
    SimpleImputer(strategy="mean"),
    StandardScaler()
).set_output(transform = "pandas")

# %%
X_pre = num_pipe.fit_transform(X)
X_pre.head()
# Out:
#          AT         V        AP        RH
# 0 -1.520448 -1.066041 -0.403535  1.141599
# 1  0.534897  0.330813 -0.309262  0.059223
# 2  1.354348  0.205475 -1.024725 -2.151400
# 3 -0.079020 -0.362884 -1.012941  0.236538
# 4 -1.055645 -1.074713  0.655349  1.633837

# %% [markdown]
# ### Step 5 - Apply Train Test split

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X_pre, Y, test_size=0.2, random_state=42)

# %%
xtrain.head()
# Out:
#             AT         V        AP        RH
# 5695 -0.152905  0.324507  0.089713  1.817999
# 7300 -1.497611 -1.153542  0.323712  0.908830
# 9066 -0.885038 -0.954892  0.293410  0.988245
# 6424  1.398679  1.223949 -0.479290 -1.082031
# 6773 -0.824586 -0.942279  0.796758  1.506499

# %%
ytrain.head()
# Out:
#           PE
# 5695  446.68
# 7300  483.54
# 9066  461.71
# 6424  437.38
# 6773  463.71

# %%
xtest.head()
# Out:
#             AT         V        AP        RH
# 1087  1.827212  1.120683 -0.125767 -1.414069
# 6308 -1.501641 -1.244984  0.044260 -0.467246
# 8021 -1.465370 -1.418408  0.399466 -1.082031
# 9483  0.150695  0.648495  0.731104 -0.002393
# 4459 -0.036032  1.128565 -0.361449  1.586599

# %%
ytest.head()
# Out:
#           PE
# 1087  429.38
# 6308  485.29
# 8021  480.40
# 9483  452.30
# 4459  446.47

# %%
xtrain.shape
# Out:
# (7621, 4)

# %%
xtest.shape
# Out:
# (1906, 4)

# %% [markdown]
# ### Step 6 - Build Neural Network

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
xtrain.shape[1]
# Out:
# 4

# %%
from keras.models import Sequential
from keras.layers import Input, Dense

# %%
# Intialize neural network
model = Sequential()

# Add Input layer
model.add(Input(shape=(xtrain.shape[1],)))

# Add Hidden Layer 1
model.add(Dense(units=8, activation="relu"))

# Add Hidden Layer 2
model.add(Dense(units=4, activation="relu"))

# Output layer
model.add(Dense(units=1, activation="linear"))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 8)                   │              40 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │              36 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │               5 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 81 (324.00 B)
#  Trainable params: 81 (324.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss="mse", optimizer="adam", metrics=["mae"])

# %%
hist = model.fit(xtrain, ytrain, validation_split=0.2, epochs=100)
# Out:
# Epoch 1/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 206675.6406 - mae: 454.2915 - val_loss: 204395.8906 - val_mae: 451.7785
# Epoch 2/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 204120.5469 - mae: 451.4770 - val_loss: 196020.9062 - val_mae: 442.4093
# Epoch 3/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 192403.8125 - mae: 438.2838 - val_loss: 173402.6094 - val_mae: 415.9789
# Epoch 4/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 166166.9375 - mae: 406.9628 - val_loss: 135929.5781 - val_mae: 367.2549
# Epoch 5/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 126979.3516 - mae: 354.0272 - val_loss: 92278.9375 - val_mae: 298.1312
# Epoch 6/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 83924.4688 - mae: 281.6191 - val_loss: 55647.7266 - val_mae: 219.1248
# Epoch 7/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 50291.2148 - mae: 205.9631 - val_loss: 34123.1484 - val_mae: 160.4001
# Epoch 8/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 32070.5938 - mae: 155.6603 - val_loss: 24600.3516 - val_mae: 134.7105
# Epoch 9/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 23705.7031 - mae: 132.4796 - val_loss: 20238.6641 - val_mae: 122.7267
# Epoch 10/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19244.9297 - mae: 119.5001 - val_loss: 17397.9746 - val_mae: 113.7369
# Epoch 11/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 16250.7715 - mae: 109.9536 - val_loss: 14926.5381 - val_mae: 105.0137
# Epoch 12/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13765.4883 - mae: 100.3268 - val_loss: 12588.3799 - val_mae: 96.0274
# Epoch 13/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 11552.1914 - mae: 91.7185 - val_loss: 10287.0791 - val_mae: 86.5513
# Epoch 14/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9396.8311 - mae: 82.8493 - val_loss: 8143.7935 - val_mae: 76.6891
# Epoch 15/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7537.3818 - mae: 74.0399 - val_loss: 6218.1763 - val_mae: 66.6386
# Epoch 16/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5451.5879 - mae: 62.6278 - val_loss: 4589.2329 - val_mae: 56.7142
# Epoch 17/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3954.8572 - mae: 52.9149 - val_loss: 3279.4253 - val_mae: 47.3450
# Epoch 18/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2947.9182 - mae: 45.0901 - val_loss: 2296.7485 - val_mae: 38.7080
# Epoch 19/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2029.8413 - mae: 36.7309 - val_loss: 1583.2291 - val_mae: 31.2718
# Epoch 20/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1426.3920 - mae: 29.7852 - val_loss: 1086.9208 - val_mae: 25.1514
# Epoch 21/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 998.5460 - mae: 24.5861 - val_loss: 746.4897 - val_mae: 20.1648
# Epoch 22/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 667.0767 - mae: 19.4016 - val_loss: 515.3949 - val_mae: 16.4201
# Epoch 23/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 477.1966 - mae: 15.8540 - val_loss: 361.0467 - val_mae: 13.6111
# Epoch 24/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 317.8524 - mae: 12.7295 - val_loss: 256.8828 - val_mae: 11.3614
# Epoch 25/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 230.5509 - mae: 10.8949 - val_loss: 186.2693 - val_mae: 9.5601
# Epoch 26/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 168.8142 - mae: 9.1895 - val_loss: 136.8807 - val_mae: 8.2100
# Epoch 27/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 122.0053 - mae: 7.8899 - val_loss: 103.8616 - val_mae: 7.1266
# Epoch 28/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 100.3516 - mae: 7.0838 - val_loss: 79.9211 - val_mae: 6.2277
# Epoch 29/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 76.8077 - mae: 6.1526 - val_loss: 63.2494 - val_mae: 5.5626
# Epoch 30/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 59.0731 - mae: 5.4879 - val_loss: 51.9002 - val_mae: 5.0758
# Epoch 31/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 50.8939 - mae: 5.0147 - val_loss: 44.0320 - val_mae: 4.7687
# Epoch 32/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 41.9335 - mae: 4.6636 - val_loss: 38.1553 - val_mae: 4.4729
# Epoch 33/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 35.4888 - mae: 4.3922 - val_loss: 34.3466 - val_mae: 4.2786
# Epoch 34/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 32.7179 - mae: 4.2219 - val_loss: 31.2947 - val_mae: 4.1313
# Epoch 35/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 30.1351 - mae: 4.0151 - val_loss: 28.9356 - val_mae: 3.9982
# Epoch 36/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 28.7935 - mae: 3.9988 - val_loss: 27.3170 - val_mae: 3.9325
# Epoch 37/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26.8451 - mae: 3.9414 - val_loss: 25.8167 - val_mae: 3.8525
# Epoch 38/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 27.6741 - mae: 3.9476 - val_loss: 24.8033 - val_mae: 3.8000
# Epoch 39/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 25.5500 - mae: 3.8682 - val_loss: 24.0315 - val_mae: 3.7699
# Epoch 40/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 23.6759 - mae: 3.7946 - val_loss: 23.4679 - val_mae: 3.7432
# Epoch 41/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 23.7202 - mae: 3.7366 - val_loss: 22.9033 - val_mae: 3.7178
# Epoch 42/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.5701 - mae: 3.6763 - val_loss: 22.9041 - val_mae: 3.7277
# Epoch 43/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.5703 - mae: 3.6644 - val_loss: 22.1681 - val_mae: 3.6701
# Epoch 44/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 22.0894 - mae: 3.7270 - val_loss: 21.7614 - val_mae: 3.6370
# Epoch 45/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.2549 - mae: 3.6429 - val_loss: 21.5908 - val_mae: 3.6379
# Epoch 46/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 22.2523 - mae: 3.6974 - val_loss: 21.3556 - val_mae: 3.6146
# Epoch 47/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.8774 - mae: 3.6860 - val_loss: 21.2715 - val_mae: 3.6007
# Epoch 48/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 21.1718 - mae: 3.6780 - val_loss: 21.4962 - val_mae: 3.6290
# Epoch 49/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 20.8554 - mae: 3.6614 - val_loss: 21.0947 - val_mae: 3.5962
# Epoch 50/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 20.5960 - mae: 3.6152 - val_loss: 20.9450 - val_mae: 3.5730
# Epoch 51/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 20.7143 - mae: 3.6243 - val_loss: 20.9188 - val_mae: 3.5629
# Epoch 52/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.4366 - mae: 3.6187 - val_loss: 20.8960 - val_mae: 3.5559
# Epoch 53/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.6013 - mae: 3.6539 - val_loss: 20.9323 - val_mae: 3.5765
# Epoch 54/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.8795 - mae: 3.5963 - val_loss: 21.5443 - val_mae: 3.6482
# Epoch 55/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.8839 - mae: 3.6177 - val_loss: 21.5200 - val_mae: 3.6481
# Epoch 56/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.6712 - mae: 3.5534 - val_loss: 20.8607 - val_mae: 3.5690
# Epoch 57/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.2424 - mae: 3.6329 - val_loss: 20.9382 - val_mae: 3.5957
# Epoch 58/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.7093 - mae: 3.5782 - val_loss: 20.8583 - val_mae: 3.5574
# Epoch 59/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 22.2577 - mae: 3.6467 - val_loss: 20.5696 - val_mae: 3.5373
# Epoch 60/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.9594 - mae: 3.6569 - val_loss: 20.7466 - val_mae: 3.5380
# Epoch 61/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.2654 - mae: 3.6241 - val_loss: 20.5735 - val_mae: 3.5414
# Epoch 62/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.5962 - mae: 3.5336 - val_loss: 20.8824 - val_mae: 3.5782
# Epoch 63/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.1338 - mae: 3.6061 - val_loss: 20.9351 - val_mae: 3.5776
# Epoch 64/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.3217 - mae: 3.6370 - val_loss: 20.7030 - val_mae: 3.5635
# Epoch 65/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.6693 - mae: 3.6318 - val_loss: 20.5581 - val_mae: 3.5451
# Epoch 66/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.9445 - mae: 3.6095 - val_loss: 20.8943 - val_mae: 3.5815
# Epoch 67/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.8309 - mae: 3.6881 - val_loss: 20.5033 - val_mae: 3.5337
# Epoch 68/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 20.6001 - mae: 3.6047 - val_loss: 21.1406 - val_mae: 3.6139
# Epoch 69/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 20.6254 - mae: 3.5958 - val_loss: 21.6730 - val_mae: 3.6564
# Epoch 70/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 20.4804 - mae: 3.6052 - val_loss: 20.8336 - val_mae: 3.5331
# Epoch 71/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.3877 - mae: 3.5318 - val_loss: 21.2426 - val_mae: 3.6171
# Epoch 72/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.5700 - mae: 3.5787 - val_loss: 20.6326 - val_mae: 3.5505
# Epoch 73/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.4956 - mae: 3.5624 - val_loss: 21.0770 - val_mae: 3.5991
# Epoch 74/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.0883 - mae: 3.5492 - val_loss: 20.5246 - val_mae: 3.5218
# Epoch 75/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.2967 - mae: 3.5983 - val_loss: 20.8486 - val_mae: 3.5708
# Epoch 76/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.7133 - mae: 3.5330 - val_loss: 21.2624 - val_mae: 3.5868
# Epoch 77/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.3071 - mae: 3.6046 - val_loss: 20.6332 - val_mae: 3.5367
# Epoch 78/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.4163 - mae: 3.5850 - val_loss: 20.6616 - val_mae: 3.5467
# Epoch 79/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.9007 - mae: 3.5349 - val_loss: 20.7633 - val_mae: 3.5277
# Epoch 80/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.9546 - mae: 3.5558 - val_loss: 20.6965 - val_mae: 3.5607
# Epoch 81/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.2357 - mae: 3.5889 - val_loss: 20.6700 - val_mae: 3.5493
# Epoch 82/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.0723 - mae: 3.5936 - val_loss: 20.5721 - val_mae: 3.5295
# Epoch 83/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.8935 - mae: 3.6540 - val_loss: 20.6025 - val_mae: 3.5270
# Epoch 84/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.8549 - mae: 3.5666 - val_loss: 20.8155 - val_mae: 3.5625
# Epoch 85/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 20.5133 - mae: 3.5480 - val_loss: 20.6597 - val_mae: 3.5519
# Epoch 86/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 20.3594 - mae: 3.5816 - val_loss: 20.9886 - val_mae: 3.5938
# Epoch 87/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 20.7430 - mae: 3.6429 - val_loss: 20.6157 - val_mae: 3.5487
# Epoch 88/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.1551 - mae: 3.5564 - val_loss: 20.6500 - val_mae: 3.5224
# Epoch 89/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.8537 - mae: 3.5479 - val_loss: 20.7917 - val_mae: 3.5564
# Epoch 90/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.5895 - mae: 3.5945 - val_loss: 20.7958 - val_mae: 3.5591
# Epoch 91/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.9181 - mae: 3.6014 - val_loss: 20.7977 - val_mae: 3.5646
# Epoch 92/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.1776 - mae: 3.5553 - val_loss: 20.4912 - val_mae: 3.5354
# Epoch 93/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.6682 - mae: 3.5968 - val_loss: 20.4669 - val_mae: 3.5388
# Epoch 94/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.6997 - mae: 3.5847 - val_loss: 20.4463 - val_mae: 3.5172
# Epoch 95/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.0238 - mae: 3.5533 - val_loss: 20.7586 - val_mae: 3.5733
# Epoch 96/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.9650 - mae: 3.5509 - val_loss: 20.5113 - val_mae: 3.5330
# Epoch 97/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.9641 - mae: 3.5725 - val_loss: 20.3924 - val_mae: 3.5121
# Epoch 98/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.3948 - mae: 3.5714 - val_loss: 20.4953 - val_mae: 3.5159
# Epoch 99/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.1623 - mae: 3.4916 - val_loss: 20.4862 - val_mae: 3.5298
# Epoch 100/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.1462 - mae: 3.5156 - val_loss: 20.3956 - val_mae: 3.5147

# %% [markdown]
# ### Plot the learning curve

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 5))
plt.plot(hist.history["loss"], label="Train Loss")
plt.plot(hist.history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Mean Squared Error")
plt.title("Learning Curve")
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluate the model

# %%
model.evaluate(xtrain, ytrain)
# Out:
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.9884 - mae: 3.5422
# [20.146699905395508, 3.5318284034729004]

# %%
model.evaluate(xtest, ytest)
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 18.7681 - mae: 3.4550
# [19.989694595336914, 3.530181884765625]

# %%
ypred_train = model.predict(xtrain)
ypred_test = model.predict(xtest)
# Out:
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
ypred_train[0:5]
# Out:
# array([[450.9357 ],
#        [478.10577],
#        [468.14478],
#        [431.4643 ],
#        [466.25977]], dtype=float32)

# %%
ytrain.head()
# Out:
#           PE
# 5695  446.68
# 7300  483.54
# 9066  461.71
# 6424  437.38
# 6773  463.71

# %%
ypred_test[0:5]
# Out:
# array([[426.43222],
#        [481.5758 ],
#        [483.2724 ],
#        [450.0285 ],
#        [446.81982]], dtype=float32)

# %%
ytest.head()
# Out:
#           PE
# 1087  429.38
# 6308  485.29
# 8021  480.40
# 9483  452.30
# 4459  446.47

# %%
from sklearn.metrics import r2_score

# %%
r2_score(ytrain, ypred_train)
# Out:
# 0.9299062490463257

# %%
r2_score(ytest, ypred_test)
# Out:
# 0.9337628483772278

# %% [markdown]
# ### From above i conclude the model is good and can be used for out of sample prediction

# %% [markdown]
# ### Step 8 - Out Of Sample prediction

# %%
url2 = "https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/refs/heads/main/test_PowerPlant.csv"
print(url2)
# Out:
# https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/refs/heads/main/test_PowerPlant.csv

# %%
xnew = pd.read_csv(url2)

# %%
xnew
# Out:
#        AT      V       AP     RH
# 0   22.49  58.82  1009.73  85.19
# 1   28.88  54.89  1007.16  46.60
# 2   27.89  73.21  1001.32  85.88
# 3   25.69  62.26  1011.38  74.08
# 4   12.16  40.81  1025.79  70.97
# ..    ...    ...      ...    ...
# 95  26.35  69.48  1008.45  70.47
# 96  11.78  39.96  1011.37  82.95
# 97   5.62  41.38  1020.91  86.21
# 98  24.96  74.99  1008.25  80.52
# 99   9.48  40.80  1023.82  78.98
#
# [100 rows x 4 columns]

# %%
num_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('standardscaler', StandardScaler())])

# %%
xnew_pre = num_pipe.transform(xnew)
xnew_pre
# Out:
#           AT         V        AP        RH
# 0   0.380410  0.356827 -0.590397  0.811615
# 1   1.238819  0.047028 -1.023041 -1.830315
# 2   1.105826  1.491180 -2.006171  0.858853
# 3   0.810286  0.628000 -0.312629  0.051007
# 4  -1.007284 -1.062888  2.113209 -0.161908
# ..       ...       ...       ...       ...
# 95  0.898948  1.197147 -0.805877 -0.196139
# 96 -1.058331 -1.129893 -0.314313  0.658261
# 97 -1.885843 -1.017956  1.291690  0.881445
# 98  0.712221  1.631496 -0.839546  0.491899
# 99 -1.367305 -1.063677  1.781571  0.386469
#
# [100 rows x 4 columns]

# %%
preds = model.predict(xnew_pre)
preds[0:5]
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# array([[444.91394],
#        [439.2221 ],
#        [429.46033],
#        [439.58972],
#        [474.07147]], dtype=float32)

# %%
xnew["PE_pred"] = preds.round(2)

# %%
xnew
# Out:
#        AT      V       AP     RH     PE_pred
# 0   22.49  58.82  1009.73  85.19  444.910004
# 1   28.88  54.89  1007.16  46.60  439.220001
# 2   27.89  73.21  1001.32  85.88  429.459991
# 3   25.69  62.26  1011.38  74.08  439.589996
# 4   12.16  40.81  1025.79  70.97  474.070007
# ..    ...    ...      ...    ...         ...
# 95  26.35  69.48  1008.45  70.47  436.690002
# 96  11.78  39.96  1011.37  82.95  471.739990
# 97   5.62  41.38  1020.91  86.21  484.029999
# 98  24.96  74.99  1008.25  80.52  436.359985
# 99   9.48  40.80  1023.82  78.98  477.929993
#
# [100 rows x 5 columns]

# %%
xnew.to_csv("Results.csv", index=False)

# %% [markdown]
# ### Save the model object

# %%
model.save("PowerModel.keras")

# %% [markdown]
# ### Load the model

# %%
from keras.models import load_model

# %%
m = load_model("/content/PowerModel.keras")
m.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 8)                   │              40 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │              36 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │               5 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 245 (984.00 B)
#  Trainable params: 81 (324.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 164 (660.00 B)
